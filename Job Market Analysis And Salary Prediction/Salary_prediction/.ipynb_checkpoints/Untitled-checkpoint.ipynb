# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("project_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56685 entries, 0 to 56684
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Experience     56685 non-null  object
#  1   UG             52703 non-null  object
#  2   Location       56685 non-null  object
#  3   PG             35645 non-null  object
#  4   Salary         56685 non-null  object
#  5   Department     54701 non-null  object
#  6   Doctorate:     1927 non-null   object
#  7   Skills         56685 non-null  object
#  8   Role Category  54687 non-null  object
# dtypes: object(9)
# memory usage: 3.9+ MB

# %%
df.head()
# Out:
#     Experience                       UG  \
# 0  0 - 1 years  Graduation Not Required
# 1  0 - 1 years             Any Graduate
# 2  0 - 1 years             Any Graduate
# 3  1 - 4 years             Any Graduate
# 4  0 - 4 years             Any Graduate
#
#                                 Location                PG  \
# 0          Hiring office located in Pune               NaN
# 1                              Bengaluru  Any Postgraduate
# 2                              Bengaluru  Any Postgraduate
# 3                              Hyderabad  Any Postgraduate
# 4  Kolkata, Mumbai, Hyderabad, Bengaluru  Any Postgraduate
#
#                 Salary                   Department Doctorate:  \
# 0  2.25-2.75 Lacs P.A.  BFSI, Investments & Trading        NaN
# 1        Not Disclosed  BFSI, Investments & Trading        NaN
# 2        Not Disclosed  BFSI, Investments & Trading        NaN
# 3        Not Disclosed  BFSI, Investments & Trading        NaN
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df_sal = df['Salary']

# %%
df_sal.to_csv('sal.csv', index=False, encoding='utf-8')

# %%
df['Salary'].value_counts()
# Out:
# Salary
# Not Disclosed                                      38587
# 3-6 Lacs P.A.                                        382
# 3-5 Lacs P.A.                                        341
# 2.5-4 Lacs P.A.                                      300
# 3-4 Lacs P.A.                                        278
# 2-3 Lacs P.A.                                        259
# 2.25-4 Lacs P.A.                                     246
# 2-4 Lacs P.A.                                        240
# 2-5 Lacs P.A.                                        206
# 3-4.5 Lacs P.A.                                      194
# 50,000-3 Lacs P.A.                                   191
# 4-6 Lacs P.A.                                        190
# 2-3.5 Lacs P.A.                                      188
# 2.5-3.5 Lacs P.A.                                    184
# 15-25 Lacs P.A.                                      158
# 10-20 Lacs P.A.                                      147
# ...

# %%
df_salary = pd.read_csv('saldf.csv')
df_salary.value_counts()
# Out:
# newSal
# 350000.0      754
# 300000.0      708
# 450000.0      639
# 400000.0      639
# 325000.0      629
# 250000.0      519
# 375000.0      477
# 275000.0      449
# 312500.0      423
# 500000.0      399
# 425000.0      386
# 550000.0      363
# 175000.0      356
# 337500.0      351
# 225000.0      310
# 600000.0      309
# 650000.0      301
# 200000.0      290
# 262500.0      265
# 750000.0      263
# 287500.0      260
# 900000.0      241
# 1500000.0     232
# 1000000.0     227
# 150000.0      226
# 475000.0      224
# 387500.0      223
# 362500.0      217
# 212500.0      217
# 2250000.0     210
# 237500.0      209
# 1100000.0     187
# 700000.0      184
# 850000.0      179
# 525000.0      166
# 2000000.0     159
# 2750000.0     156
# 3250000.0     151
# 0.0           149
# 800000.0      137
# 187500.0      134
# 1250000.0     134
# 1350000.0     132
# 1200000.0     124
# 950000.0      122
# 162500.0      119
# 1300000.0     117
# 1750000.0     116
# 1700000.0     111
# ...
