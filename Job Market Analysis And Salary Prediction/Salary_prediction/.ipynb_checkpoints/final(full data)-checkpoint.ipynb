# %%
import numpy as np
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pickle

# %%
df = pd.read_csv("project_data.csv")

# %%
df.head()
# Out:
#     Experience                       UG  \
# 0  0 - 1 years  Graduation Not Required
# 1  0 - 1 years             Any Graduate
# 2  0 - 1 years             Any Graduate
# 3  1 - 4 years             Any Graduate
# 4  0 - 4 years             Any Graduate
#
#                                 Location                PG  \
# 0          Hiring office located in Pune               NaN
# 1                              Bengaluru  Any Postgraduate
# 2                              Bengaluru  Any Postgraduate
# 3                              Hyderabad  Any Postgraduate
# 4  Kolkata, Mumbai, Hyderabad, Bengaluru  Any Postgraduate
#
#                 Salary                   Department       Role Category
# 0  2.25-2.75 Lacs P.A.  BFSI, Investments & Trading             Lending
# 1        Not Disclosed  BFSI, Investments & Trading  Banking Operations
# 2        Not Disclosed  BFSI, Investments & Trading             Lending
# 3        Not Disclosed  BFSI, Investments & Trading  Banking Operations
# 4        Not Disclosed  BFSI, Investments & Trading             Lending

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56685 entries, 0 to 56684
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Experience     56685 non-null  object
#  1   UG             52703 non-null  object
#  2   Location       56685 non-null  object
#  3   PG             35645 non-null  object
#  4   Salary         56685 non-null  object
#  5   Department     54701 non-null  object
#  6   Role Category  54687 non-null  object
# dtypes: object(7)
# memory usage: 3.0+ MB

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# ## Experience

# %%
# Function to process the Experience column
def process_experience(exp):
    exp = exp.lower().strip()  # Standardize the string
    if "no fixed duration" in exp:  # Handle "No fixed duration"
        return 0
    elif "months" in exp:  # Convert months to years
        months = [int(s) for s in exp.split() if s.isdigit()]
        if months:
            return months[0] / 12
        else:  # Handle ambiguous "few months"
            return 0.25  # Default to 0.25 years (~3 months)
    elif "years" in exp and "-" in exp:  # Handle ranges of years
        years = [float(x) for x in exp.split("years")[0].split("-")]
        mean_years = sum(years) / len(years)
        # Cap at a maximum threshold (e.g., 30 years)
        return min(mean_years, 30)
    elif "years" in exp:  # Handle single years (e.g., "15 years")
        return min(float(exp.split()[0]), 30)
    elif "year" in exp:  # Handle ambiguous "a year" or "1 year"
        return 1
    elif "month" in exp: # Handle ambiguous "a month" or "1 month"
        return 0

# %%
# Apply the function to the Experience column
df['Processed_Experience'] = df['Experience'].apply(process_experience)

# %%
# Round the processed experience values to 2 decimal places
df['Processed_Experience'] = df['Processed_Experience'].round(2)

# %%
# Define bins and labels for the ranges
bins = [0, 1, 3, 5, 10, 15, float('inf')]
labels = ['Entry-level', 'Junior', 'Mid-level', 'Experienced', 'Senior', 'Expert']

# Create a new column for categorized experience
df['Experience_Category'] = pd.cut(df['Processed_Experience'], bins=bins, labels=labels, right=False)

# %%
df['Experience_Category'].value_counts()
# Out:
# Experience_Category
# Experienced    22165
# Mid-level      16052
# Junior         11372
# Senior          3564
# Entry-level     2013
# Expert          1519
# Name: count, dtype: int64

# %% [markdown]
# ## UG PG

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56685 entries, 0 to 56684
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Experience            56685 non-null  object
#  1   UG                    52703 non-null  object
#  2   Location              56685 non-null  object
#  3   PG                    35645 non-null  object
#  4   Salary                56685 non-null  object
#  5   Department            54701 non-null  object
#  6   Role Category         54687 non-null  object
#  7   Processed_Experience  56685 non-null  float64
#  8   Experience_Category   56685 non-null  category
# dtypes: category(1), float64(1), object(7)
# memory usage: 3.5+ MB

# %%
df['UG'] = df['UG'].fillna('NA')
df['PG'] = df['PG'].fillna('NA')

# %%
# Convert the 'UG' column to binary encoding based on degree requirements
def encode_degree_requirement(ug_value):
    if pd.isna(ug_value) or ug_value in ['Graduation Not Required', 'NA']:
        return 0  # No degree required
    else:
        return 1  # Degree required

# Apply the function to encode the UG column
df['UG_Encoded'] = df['UG'].apply(encode_degree_requirement)

# %%
df['UG_Encoded'].value_counts()
# Out:
# UG_Encoded
# 1    50223
# 0     6462
# Name: count, dtype: int64

# %%
# Function to encode the 'PG' column based on multiple conditions
def encode_pg_degree_requirement(pg_value):
    if pd.isna(pg_value):  # Check for missing or NaN values
        return 0  # No degree required
    pg_value = pg_value.lower()  # Convert to lowercase for case-insensitivity
    # Conditions for "No degree required"
    no_degree_conditions = ['post graduation not required', 'not applicable', 'na', 'none', 'no post graduation']
    if any(condition in pg_value for condition in no_degree_conditions):
        return 0  # No degree required
    else:
        return 1  # Degree required

# %%
df['PG_Encoded'] = df['PG'].apply(encode_pg_degree_requirement)

# %%
df['PG_Encoded'].value_counts()
# Out:
# PG_Encoded
# 1    34755
# 0    21930
# Name: count, dtype: int64

# %% [markdown]
# ## Location

# %%
# df.drop('Location', axis=1, inplace=True)

# %%
def rmhirefromvalue(value):
    if 'Hiring office located in' in value:
        value = value.split('located in')[1].strip()
        return value
    else:
        
        return value

# %%
df['Location']=df['Location'].apply(rmhirefromvalue)

# %%
def extract_city(location):
    # Rule 1: If comma-separated, take the first part
    if ',' in location:
        return location.split(',')[0].strip()
    # Rule 2: For addresses, use a regex pattern to find potential city-like words
    # Example: Capitalize words with more than 2 characters
    match = re.search(r'\b[A-Z][a-zA-Z]+\b', location)
    if match:
        return match.group(0)
    # Rule 3: Return as is if no pattern matches
    return location

# %%
df['City'] = df['Location'].apply(extract_city)

# %%
cities_list = ['Bengaluru', 'Mumbai', 'Delhi', 'Hyderabad', 'Chennai', 'Pune', 'Kolkata', 
               'Ahmedabad', 'Jaipur', 'Coimbatore', 'Indore', 'Surat', 'Vadodara', 'Lucknow', 
               'Nagpur', 'Bhopal', 'Chandigarh', 'Thiruvananthapuram', 'Visakhapatnam', 'Patna','Gurugram']

# %%
def func_city(location):
    values=[]
    if ',' in location:
        values.extend(location.split(','))
    else:
        values.append(location)
    for v in values:
        for c in cities_list:
            if v in c :
                return c
    return location

# %%
def func_city1(location):
    # values=[]
    # if ',' in location:
    #     values.extend(location.split(','))
    # else:
    #     values.append(location)
    # for v in values:
    #     for c in cities_list:
    #         if v in c :
    #             return c
    # return location
    for city in cities_list:
        if city in location:
            return city
    return location

# %%
df['City'] = df['City'].replace("New Delhi","Delhi")
df['City'] = df['City'].replace("Navi","Mumbai")
df['City'] = df['City'].replace("Bengalore","Bengaluru")

# %%
def value_conversion(location):
    for city in cities_list:
        if city.lower() in  location.lower():
            return city
    return location

# %%
df['City'] = df['City'].apply(value_conversion)

# %%
mumbai_city = [
        "Colaba", "Fort", "Churchgate", "Marine Lines", 
        "Nariman Point", "Cuffe Parade", "Malabar Hill", 
        "Girgaon (Girgaum)", "Dadar", "Tardeo",
        "Byculla", "Parel", "Lower Parel", 
        "Worli", "Mahalaxmi",
        "Bandra", "Khar", "Santacruz", "Vile Parle", 
        "Andheri", "Jogeshwari", "Goregaon", "Malad", 
        "Kandivali", "Borivali", "Dahisar",
        "Kurla", "Chembur", "Ghatkopar", 
        "Vikhroli", "Bhandup", "Mulund",
        "Dockyard Road", "Sewri", "Wadala", 
        "Mankhurd", "Govandi",
        "Powai", "Chandivali",
        "Vashi", "Nerul", "Kharghar", "Panvel",
        "Thane", "Kalyan", "Dombivli", 
        "Ambernath", "Ulhasnagar", "Vasai-Virar"
    ]

# %%
delhi_city = [
        "Connaught Place", "Karol Bagh", "Daryaganj", 
        "Paharganj", "Pragati Maidan",
        "Kashmere Gate", "Civil Lines", "Model Town", 
        "GTB Nagar", "Shakti Nagar",
        "Saket", "Hauz Khas", "Greater Kailash", 
        "Lajpat Nagar", "Defence Colony", "Vasant Kunj", 
        "Mehrauli", "Malviya Nagar",
        "Rajouri Garden", "Punjabi Bagh", "Janakpuri", 
        "Tilak Nagar", "Uttam Nagar", "Paschim Vihar",
        "Preet Vihar", "Laxmi Nagar", "Mayur Vihar", 
        "Patparganj", "Anand Vihar", "Shahdara",
        "Chanakyapuri", "Sarojini Nagar", "RK Puram", 
        "Lodhi Colony", "Jor Bagh", "Diplomatic Enclave",
        "Rohini", "Pitampura", "Ashok Vihar", 
        "Shalimar Bagh", "Narela",
        "Dwarka", "Najafgarh", "Palam", 
        "Vasant Vihar", "Mahipalpur",
        "Seelampur", "Yamuna Vihar", "Shastri Park", 
        "Bhajanpura", "Khajuri Khas",
        "Bawana", "Alipur", "Najafgarh Rural", 
        "Narela Rural"
    ]

# %%
def mumbai_cities_filter(location):
    for city in mumbai_city:
        if city.lower() in  location.lower():
            return 'Mumbai'
    return location

# %%
def delhi_cities_filter(location):
    for city in delhi_city:
        if city.lower() in  location.lower():
            return 'Delhi'
    return location

# %%
df['City'] = df['City'].apply(delhi_cities_filter)
df['City'] = df['City'].apply(mumbai_cities_filter)

# %%
df['City'].value_counts().head(20)
# Out:
# City
# Bengaluru     10959
# Mumbai         6652
# Hyderabad      6173
# Pune           5453
# Chennai        3800
# Gurugram       3112
# Noida          3044
# Kolkata        2552
# Ahmedabad      1313
# Coimbatore      757
# Jaipur          584
# Kochi           550
# Mohali          393
# Vadodara        334
# Nagpur          315
# Delhi           273
# Surat           266
# Lucknow         257
# Chandigarh      243
# Faridabad       217
# Name: count, dtype: int64

# %%
top_cities=['Bengaluru','Mumbai',
'Hyderabad','Noida',
'Pune','Chennai',
'Gurugram',
'Kolkata','Ahmedabad',
'Mohali','Kochi',
'Jaipur','Coimbatore',
'Delhi','Vadodara',
'Lucknow','Madurai',
'Surat','Faridabad',
'Chandigarh']

# %%
def otherCategory(value):
    for city in top_cities:
        if value == city:
            return city
    return 'other'

# %%
df['City']= df['City'].apply(otherCategory)

# %% [markdown]
# ## Department & Role Category

# %%
df = df.dropna(subset=['Department'])

# %%
df['Role Category'] = df['Role Category'].fillna('Others')

# %%
# Define the threshold for grouping departments
dept_threshold = 180

# Identify rare departments
rare_departments = df['Department'].value_counts()[df['Department'].value_counts() < dept_threshold].index

# Replace rare departments with "Others"
df['Department'] = df['Department'].replace(rare_departments, 'Others')

# %%
# Define the threshold for grouping role categories
role_threshold = 100

# Identify rare role categories
rare_roles = df['Role Category'].value_counts()[df['Role Category'].value_counts() < role_threshold].index

# Replace rare role categories with "Others"
df['Role Category'] = df['Role Category'].replace(rare_roles, 'Others')

# %%
# Ensure at least one unique role category per department
for dept in df['Department'].unique():
    # Subset data for the current department
    dept_roles = df[df['Department'] == dept]['Role Category']
    
    # Check if all roles for this department are "Others"
    if dept_roles.nunique() == 1 and dept_roles.iloc[0] == 'Others':
        # Find the most frequent rare role for this department
        original_roles = df[(df['Department'] == dept) & (df['Role Category'].isin(rare_roles))]
        if not original_roles.empty:
            most_frequent_role = original_roles['Role Category'].mode()[0]

            # Replace "Others" with the most frequent role
            df.loc[
                (df['Department'] == dept) & (df['Role Category'] == 'Others'),
                'Role Category'
            ] = most_frequent_role

# %%
# Correct "Others - Finance" anomaly
df.loc[(df['Department'] == 'Others') & (df['Role Category'] == 'Finance'), 'Department'] = 'Finance & Accounting'

# %%
# Append department name to "Others" role for better specificity
df.loc[df['Role Category'] == 'Others', 'Role Category'] = df['Department'] + " - Others"

# %%
# Define the threshold for grouping role categories
role_threshold = 80

# Identify rare role categories
rare_roles = df['Role Category'].value_counts()[df['Role Category'].value_counts() < role_threshold].index

# Replace rare role categories with "Others"
df['Role Category'] = df['Role Category'].replace(rare_roles, 'Others')

# %%
# Create a combined feature for Department and Role Category
df['Department_Role'] = df['Department'] + " - " + df['Role Category']

# %%
df.head()
# Out:
#     Experience                       UG  \
# 0  0 - 1 years  Graduation Not Required
# 1  0 - 1 years             Any Graduate
# 2  0 - 1 years             Any Graduate
# 3  1 - 4 years             Any Graduate
# 4  0 - 4 years             Any Graduate
#
#                                 Location                PG  \
# 0                                   Pune                NA
# 1                              Bengaluru  Any Postgraduate
# 2                              Bengaluru  Any Postgraduate
# 3                              Hyderabad  Any Postgraduate
# 4  Kolkata, Mumbai, Hyderabad, Bengaluru  Any Postgraduate
#
#                 Salary                   Department       Role Category  \
# 0  2.25-2.75 Lacs P.A.  BFSI, Investments & Trading             Lending
# 1        Not Disclosed  BFSI, Investments & Trading  Banking Operations
# 2        Not Disclosed  BFSI, Investments & Trading             Lending
# 3        Not Disclosed  BFSI, Investments & Trading  Banking Operations
# 4        Not Disclosed  BFSI, Investments & Trading             Lending
#
#    Processed_Experience Experience_Category  UG_Encoded  PG_Encoded  \
# 0                   0.5         Entry-level           0           0
# 1                   0.5         Entry-level           1           1
# 2                   0.5         Entry-level           1           1
# 3                   2.5              Junior           1           1
# 4                   2.0              Junior           1           1
#
#         City                                   Department_Role
# 0       Pune             BFSI, Investments & Trading - Lending
# 1  Bengaluru  BFSI, Investments & Trading - Banking Operations
# 2  Bengaluru             BFSI, Investments & Trading - Lending
# 3  Hyderabad  BFSI, Investments & Trading - Banking Operations
# 4    Kolkata             BFSI, Investments & Trading - Lending

# %%
# convert all qualitative columns to quantitative ones
from sklearn.preprocessing import LabelEncoder

# create encoders
df['Experience_Category'] = LabelEncoder().fit_transform(df['Experience_Category'])
df['Department_Role'] = LabelEncoder().fit_transform(df['Department_Role'])
df['Department'] = LabelEncoder().fit_transform(df['Department'])
df['Role Category'] = LabelEncoder().fit_transform(df['Role Category'])
df['City'] = LabelEncoder().fit_transform(df['City'])

# %%
df=df[['Experience_Category', 'City', 'UG_Encoded', 'PG_Encoded', 'Department', 'Role Category', 'Salary']]

# %% [markdown]
# ## Salary

# %%
# Filter records where Salary is "Not Disclosed"
not_disclosed_df = df[df['Salary'] == "Not Disclosed"].copy()

# %%
df = df.loc[df['Salary'] != 'Not Disclosed']

# %%
def remove_parentheses_content(salary):
    if pd.isna(salary):
        return salary
    return re.sub(r'\(.*?\)', '', salary).strip()
df['Salary'] = df['Salary'].apply(remove_parentheses_content)

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 3-6 Lacs P.A.            378
# 3-5 Lacs P.A.            322
# 2.5-4 Lacs P.A.          293
# 3-4 Lacs P.A.            266
# 2-3 Lacs P.A.            254
# 2.25-4 Lacs P.A.         245
# 2-4 Lacs P.A.            226
# 2-5 Lacs P.A.            204
# 3-4.5 Lacs P.A.          188
# 2-3.5 Lacs P.A.          185
# 50,000-3 Lacs P.A.       185
# 4-6 Lacs P.A.            180
# 2.5-3.5 Lacs P.A.        177
# 15-25 Lacs P.A.          146
# 10-20 Lacs P.A.          140
# Unpaid                   136
# 5-10 Lacs P.A.           133
# 2.5-5 Lacs P.A.          132
# 2.5-4.25 Lacs P.A.       129
# 3-8 Lacs P.A.            127
# 4-9 Lacs P.A.            126
# 1-3 Lacs P.A.            124
# 3-7 Lacs P.A.            121
# 2.5-3 Lacs P.A.          119
# 15-30 Lacs P.A.          117
# 3-5.5 Lacs P.A.          116
# 2.75-4 Lacs P.A.         115
# 4-8 Lacs P.A.            110
# 4-7 Lacs P.A.            109
# 2.5-5.5 Lacs P.A.        107
# 5-8 Lacs P.A.            107
# 5-7 Lacs P.A.            106
# 2.5-4.5 Lacs P.A.        104
# 15-20 Lacs P.A.          103
# 3-3.5 Lacs P.A.          103
# 1-4 Lacs P.A.            102
# 10-15 Lacs P.A.          101
# 8-10 Lacs P.A.           101
# 4-5 Lacs P.A.            100
# 1.5-2.5 Lacs P.A.         96
# 1.75-3 Lacs P.A.          96
# 8-12 Lacs P.A.            96
# 2-2.5 Lacs P.A.           94
# 25-35 Lacs P.A.           89
# 1-2 Lacs P.A.             88
# 1.5-3 Lacs P.A.           88
# 25-40 Lacs P.A.           86
# 20-25 Lacs P.A.           85
# 2.5-6 Lacs P.A.           84
# 2-6 Lacs P.A.             83
# 1.75-2.5 Lacs P.A.        83
# 6-12 Lacs P.A.            80
# 3.5-5 Lacs P.A.           80
# 10-12 Lacs P.A.           79
# 2.25-3.75 Lacs P.A.       79
# 20-30 Lacs P.A.           78
# 2-4.5 Lacs P.A.           77
# 12-22 Lacs P.A.           77
# 6-8 Lacs P.A.             77
# 3.5-4.5 Lacs P.A.         75
# 5-6 Lacs P.A.             75
# 2.25-3 Lacs P.A.          72
# 3.5-6 Lacs P.A.           72
# 12-15 Lacs P.A.           71
# 20-35 Lacs P.A.           70
# 7-10 Lacs P.A.            69
# 18-25 Lacs P.A.           69
# 1-6 Lacs P.A.             69
# 3.5-5.5 Lacs P.A.         69
# 25-30 Lacs P.A.           69
# 1.5-2 Lacs P.A.           68
# 1-5 Lacs P.A.             67
# 2-3.75 Lacs P.A.          67
# 3.25-4.5 Lacs P.A.        67
# 12-18 Lacs P.A.           67
# 1.5-3.5 Lacs P.A.         66
# 3-4.25 Lacs P.A.          65
# 1.8-2.4 Lacs P.A.         64
# 1.8-3 Lacs P.A.           63
# 5-15 Lacs P.A.            61
# 6-10 Lacs P.A.            61
# 6-9 Lacs P.A.             60
# 1-3.5 Lacs P.A.           60
# 2.25-3.5 Lacs P.A.        60
# 5-12 Lacs P.A.            59
# 4-5.5 Lacs P.A.           59
# 3-4.75 Lacs P.A.          59
# 2-3.25 Lacs P.A.          58
# 5-9 Lacs P.A.             58
# 1-2.5 Lacs P.A.           55
# 30-35 Lacs P.A.           54
# 3-6.5 Lacs P.A.           54
# 50,000-2.5 Lacs P.A.      53
# 4-6.5 Lacs P.A.           51
# 2-7 Lacs P.A.             51
# 4-4.5 Lacs P.A.           50
# 2.75-3.5 Lacs P.A.        49
# 12-20 Lacs P.A.           48
# 2.75-3.75 Lacs P.A.       48
# 3.5-4 Lacs P.A.           47
# 1.75-2.25 Lacs P.A.       47
# 1.5-2.25 Lacs P.A.        47
# 2.4-3 Lacs P.A.           46
# 2.75-4.25 Lacs P.A.       46
# 30-45 Lacs P.A.           46
# 8-18 Lacs P.A.            45
# 3-3.75 Lacs P.A.          45
# 2.4-3.6 Lacs P.A.         45
# 50,000-2 Lacs P.A.        45
# 2.75-4.5 Lacs P.A.        44
# 2.75-3 Lacs P.A.          43
# 7-8 Lacs P.A.             43
# 7-9 Lacs P.A.             43
# 2.5-3.25 Lacs P.A.        43
# 2.25-4.25 Lacs P.A.       43
# 10-14 Lacs P.A.           42
# 6-7 Lacs P.A.             42
# 10-18 Lacs P.A.           41
# 7-12 Lacs P.A.            41
# 15-18 Lacs P.A.           40
# 2-5.5 Lacs P.A.           40
# 2-2.75 Lacs P.A.          40
# 1.75-3.5 Lacs P.A.        40
# 8-15 Lacs P.A.            40
# 9-12 Lacs P.A.            39
# 2.5-3.75 Lacs P.A.        39
# 30-40 Lacs P.A.           39
# 1.25-3 Lacs P.A.          38
# 1-4.5 Lacs P.A.           38
# 6-16 Lacs P.A.            38
# 2-6.5 Lacs P.A.           38
# 4.25-5.5 Lacs P.A.        38
# 3-3.6 Lacs P.A.           37
# 1-3.25 Lacs P.A.          37
# 1.2-1.8 Lacs P.A.         37
# 1.5-4 Lacs P.A.           37
# 1.25-2 Lacs P.A.          37
# 1.8-3.6 Lacs P.A.         36
# 1.25-1.75 Lacs P.A.       36
# 4.75-5.5 Lacs P.A.        35
# 3.75-5 Lacs P.A.          35
# 15-22.5 Lacs P.A.         35
# 1.75-2.75 Lacs P.A.       35
# 3.5-7 Lacs P.A.           35
# 7-15 Lacs P.A.            33
# 10-16 Lacs P.A.           33
# 2.75-4.75 Lacs P.A.       33
# 2.75-3.25 Lacs P.A.       33
# 18-30 Lacs P.A.           32
# 1.75-2 Lacs P.A.          32
# 2.25-4.5 Lacs P.A.        32
# 2.25-5 Lacs P.A.          32
# 2.25-3.25 Lacs P.A.       32
# 2.5-4.75 Lacs P.A.        31
# 50,000-70,000 P.A.        31
# 3.5-4.75 Lacs P.A.        31
# 2.75-5 Lacs P.A.          30
# 35-45 Lacs P.A.           30
# 1-1.5 Lacs P.A.           30
# 1.25-2.25 Lacs P.A.       30
# 6-7.5 Lacs P.A.           30
# 5-7.5 Lacs P.A.           30
# 3-7.5 Lacs P.A.           29
# 1.25-4 Lacs P.A.          29
# 2.25-2.75 Lacs P.A.       28
# 50,000-2.75 Lacs P.A.     28
# 1.5-3.75 Lacs P.A.        28
# 1.25-2.5 Lacs P.A.        28
# 7-17 Lacs P.A.            27
# 3.5-4.25 Lacs P.A.        27
# 1.75-3.25 Lacs P.A.       27
# 1.5-2.75 Lacs P.A.        27
# 4.5-5.5 Lacs P.A.         27
# 3-3.25 Lacs P.A.          26
# 1.5-1.75 Lacs P.A.        26
# 10,000/month              26
# 50,000-60,000 P.A.        26
# 2.5-7.5 Lacs P.A.         25
# 3.6-4.8 Lacs P.A.         25
# 3.25-5.5 Lacs P.A.        25
# 3.25-5 Lacs P.A.          25
# 1.44-1.8 Lacs P.A.        25
# 4.5-6 Lacs P.A.           25
# 40-50 Lacs P.A.           25
# 7-11 Lacs P.A.            25
# 14-24 Lacs P.A.           25
# 35-60 Lacs P.A.           25
# 9-15 Lacs P.A.            24
# 35-50 Lacs P.A.           24
# 2-2.25 Lacs P.A.          24
# 12-14 Lacs P.A.           24
# 10-17 Lacs P.A.           24
# 1-2.75 Lacs P.A.          24
# 9-19 Lacs P.A.            23
# 1-2.25 Lacs P.A.          23
# 1.2-2.4 Lacs P.A.         23
# 4.5-7 Lacs P.A.           23
# 1.25-3.25 Lacs P.A.       23
# 4-8.5 Lacs P.A.           23
# 3.5-6.5 Lacs P.A.         23
# 3.75-5.5 Lacs P.A.        22
# 50,000-2.25 Lacs P.A.     22
# 2.25-5.5 Lacs P.A.        22
# 2-4.25 Lacs P.A.          22
# 1-3.75 Lacs P.A.          22
# 3-4.2 Lacs P.A.           21
# 18-20 Lacs P.A.           21
# 3.25-6 Lacs P.A.          21
# 8-14 Lacs P.A.            21
# 15-27.5 Lacs P.A.         21
# 5,000/month               21
# 6-11 Lacs P.A.            21
# 8-16 Lacs P.A.            20
# 5-14 Lacs P.A.            20
# 3.5-7.5 Lacs P.A.         20
# 9-18 Lacs P.A.            20
# 25-32.5 Lacs P.A.         20
# 40-60 Lacs P.A.           20
# 5-6.5 Lacs P.A.           20
# 1-1.25 Lacs P.A.          19
# 15,000/month              19
# 5-13 Lacs P.A.            19
# 50,000-1 Lacs P.A.        19
# 1.5-5 Lacs P.A.           18
# 3-4.8 Lacs P.A.           18
# 2.4-4.8 Lacs P.A.         18
# 4.5-9 Lacs P.A.           18
# 2.4-4.2 Lacs P.A.         18
# 20-32.5 Lacs P.A.         18
# 50,000-80,000 P.A.        18
# 8-13 Lacs P.A.            18
# 35-40 Lacs P.A.           18
# 2.25-6 Lacs P.A.          18
# 18-27.5 Lacs P.A.         18
# 1.25-2.75 Lacs P.A.       18
# 6-8.5 Lacs P.A.           17
# 1.75-4 Lacs P.A.          17
# 6-15 Lacs P.A.            17
# 3.6-6 Lacs P.A.           17
# 3.5-8.5 Lacs P.A.         17
# 2.25-6.5 Lacs P.A.        17
# 4-7.5 Lacs P.A.           17
# 6-13 Lacs P.A.            17
# 13-15 Lacs P.A.           17
# 6-14 Lacs P.A.            17
# 5-8.5 Lacs P.A.           17
# 9-10 Lacs P.A.            17
# 20-27.5 Lacs P.A.         17
# 1-5.5 Lacs P.A.           16
# 4.75-6 Lacs P.A.          16
# 1.25-3.75 Lacs P.A.       16
# 5-11 Lacs P.A.            16
# 18-22.5 Lacs P.A.         16
# 4.5-9.5 Lacs P.A.         16
# 9-11 Lacs P.A.            16
# 1.2-1.44 Lacs P.A.        16
# 1.25-3.5 Lacs P.A.        16
# 4.5-6.5 Lacs P.A.         16
# 8-9 Lacs P.A.             15
# 50,000 P.A.               15
# 10-13 Lacs P.A.           15
# 8,000/month               15
# 5.5-12 Lacs P.A.          15
# 2.75-6 Lacs P.A.          15
# 1-1.75 Lacs P.A.          15
# 3.25-4 Lacs P.A.          15
# 1.75-4.5 Lacs P.A.        15
# 9-16 Lacs P.A.            15
# 18-33 Lacs P.A.           15
# 1.25-5 Lacs P.A.          15
# 2.16-3 Lacs P.A.          15
# 22.5-25 Lacs P.A.         15
# 2.5-2.75 Lacs P.A.        15
# 12-16 Lacs P.A.           15
# 6.5-7.5 Lacs P.A.         15
# 1.44-2.16 Lacs P.A.       14
# 8-11 Lacs P.A.            14
# 1-4.25 Lacs P.A.          14
# 1.75-3.75 Lacs P.A.       14
# 14-15 Lacs P.A.           14
# 16-18 Lacs P.A.           14
# 1.5-5.5 Lacs P.A.         14
# 7-13 Lacs P.A.            14
# 1.75-4.75 Lacs P.A.       14
# 1.8-2.16 Lacs P.A.        14
# 2.75-5.5 Lacs P.A.        14
# 16-25 Lacs P.A.           14
# 2.25-2.5 Lacs P.A.        14
# 3.75-6 Lacs P.A.          13
# 7.5-10 Lacs P.A.          13
# 1.8-4.2 Lacs P.A.         13
# 4.8-6 Lacs P.A.           13
# 4.75-7.5 Lacs P.A.        13
# 1.5-4.5 Lacs P.A.         13
# 1.44-2.4 Lacs P.A.        13
# 5.5-8 Lacs P.A.           13
# 2.25-4.75 Lacs P.A.       12
# 9-14 Lacs P.A.            12
# 50,000-1.5 Lacs P.A.      12
# 1.25-4.25 Lacs P.A.       12
# 50-60 Lacs P.A.           12
# 7-14 Lacs P.A.            12
# 12-17 Lacs P.A.           12
# 12-19 Lacs P.A.           12
# 3.75-4.25 Lacs P.A.       12
# 13-23 Lacs P.A.           12
# 5-5.5 Lacs P.A.           12
# 4.5-7.5 Lacs P.A.         12
# 4.25-6 Lacs P.A.          12
# 1.5-3.25 Lacs P.A.        11
# 20-22.5 Lacs P.A.         11
# 4.5-8 Lacs P.A.           11
# 2-4.75 Lacs P.A.          11
# 4.5-5 Lacs P.A.           11
# 1.25-1.5 Lacs P.A.        11
# 16-22.5 Lacs P.A.         11
# 7.5-12 Lacs P.A.          11
# 5.5-7 Lacs P.A.           11
# 5.5-6.5 Lacs P.A.         11
# 3.25-7 Lacs P.A.          11
# 3.6-4.2 Lacs P.A.         11
# 2.5-7 Lacs P.A.           11
# 11-18 Lacs P.A.           11
# 1.25-4.5 Lacs P.A.        10
# 2.75-7.75 Lacs P.A.       10
# 3-5.4 Lacs P.A.           10
# 14-16 Lacs P.A.           10
# 2.25-7.25 Lacs P.A.       10
# 5.5-7.5 Lacs P.A.         10
# 2.5 Lacs P.A.             10
# 11-21 Lacs P.A.           10
# 6.5-8.5 Lacs P.A.         10
# 0 P.A.                    10
# 3.25-4.25 Lacs P.A.       10
# 3.75-4.5 Lacs P.A.         9
# 5.5-6 Lacs P.A.            9
# 1.8-6 Lacs P.A.            9
# 14-20 Lacs P.A.            9
# 3.25-6.5 Lacs P.A.         9
# 14-22.5 Lacs P.A.          9
# 7-16 Lacs P.A.             9
# 4.8-7.2 Lacs P.A.          9
# 3.25-3.75 Lacs P.A.        9
# 11-12 Lacs P.A.            9
# 22.5-37.5 Lacs P.A.        9
# 60,000-1 Lacs P.A.         9
# 6.5-8 Lacs P.A.            9
# 3.75-7.5 Lacs P.A.         8
# 3.5-8 Lacs P.A.            8
# 7-8.5 Lacs P.A.            8
# 9-13 Lacs P.A.             8
# 16-20 Lacs P.A.            8
# 4.2-5.4 Lacs P.A.          8
# 2.4-6 Lacs P.A.            8
# 1.2-3.6 Lacs P.A.          8
# 3.75-4 Lacs P.A.           8
# 12,000/month               8
# 60,000-70,000 P.A.         8
# 2.16-2.4 Lacs P.A.         8
# 1.75-4.25 Lacs P.A.        8
# 13-18 Lacs P.A.            8
# 4.2-6 Lacs P.A.            8
# 1.56-1.8 Lacs P.A.         8
# 10-19 Lacs P.A.            8
# 20,000/month               8
# 80,000-3 Lacs P.A.         8
# 22.5-27.5 Lacs P.A.        8
# 1.5-6.5 Lacs P.A.          8
# 5.5-8.5 Lacs P.A.          8
# 6.5-12 Lacs P.A.           7
# 2.16-2.64 Lacs P.A.        7
# 45-60 Lacs P.A.            7
# 1.5-4.25 Lacs P.A.         7
# 6-9.5 Lacs P.A.            7
# 45-50 Lacs P.A.            7
# 1.75-5.5 Lacs P.A.         7
# 80,000-1.25 Lacs P.A.      7
# 80,000-2 Lacs P.A.         7
# 60-70 Lacs P.A.            7
# 4-4.25 Lacs P.A.           7
# 1.5-4.75 Lacs P.A.         7
# 12-13 Lacs P.A.            7
# 17-20 Lacs P.A.            7
# 22.5-32.5 Lacs P.A.        7
# 1.2-2.16 Lacs P.A.         7
# 8.5-10 Lacs P.A.           7
# 4.25-5 Lacs P.A.           7
# 3.75-8 Lacs P.A.           7
# 6.5-10 Lacs P.A.           7
# 35-55 Lacs P.A.            7
# 4-4.75 Lacs P.A.           7
# 30-37.5 Lacs P.A.          7
# 4.75-8 Lacs P.A.           7
# 3.25-8.25 Lacs P.A.        7
# 2.16-4.2 Lacs P.A.         7
# 13-14 Lacs P.A.            7
# 5.5-10 Lacs P.A.           7
# 3.5-3.75 Lacs P.A.         7
# 4.5-4.75 Lacs P.A.         7
# 19-25 Lacs P.A.            7
# 50-55 Lacs P.A.            7
# 4.2-4.8 Lacs P.A.          7
# 3.25-3.5 Lacs P.A.         6
# 96,000-1.44 Lacs P.A.      6
# 7.5-8 Lacs P.A.            6
# 45-55 Lacs P.A.            6
# 25-27.5 Lacs P.A.          6
# 4.5-8.5 Lacs P.A.          6
# 7-9.5 Lacs P.A.            6
# 1.25-6.25 Lacs P.A.        6
# 1.5-6 Lacs P.A.            6
# 1.25-4.75 Lacs P.A.        6
# 6-9.6 Lacs P.A.            6
# 1.8-2.04 Lacs P.A.         6
# 8.5-12 Lacs P.A.           6
# 50,000-1.25 Lacs P.A.      6
# 1.56-2.16 Lacs P.A.        6
# 6.5-9 Lacs P.A.            6
# 50-80 Lacs P.A.            6
# 3.36-3.84 Lacs P.A.        6
# 14-17 Lacs P.A.            6
# 6-7.2 Lacs P.A.            6
# 15-19 Lacs P.A.            6
# 2.25-7 Lacs P.A.           6
# 2.64-3 Lacs P.A.           6
# 17-22.5 Lacs P.A.          6
# 2.16-3.6 Lacs P.A.         6
# 96,000-1.2 Lacs P.A.       6
# 50-70 Lacs P.A.            6
# 2.75-7 Lacs P.A.           5
# 7.5-11 Lacs P.A.           5
# 40-45 Lacs P.A.            5
# 6-8.4 Lacs P.A.            5
# 1.75-6.75 Lacs P.A.        5
# 2.4-5.4 Lacs P.A.          5
# 6-6.5 Lacs P.A.            5
# 50,000-90,000 P.A.         5
# 3 Lacs P.A.                5
# 27.5-40 Lacs P.A.          5
# 12-24 Lacs P.A.            5
# 3.75-4.75 Lacs P.A.        5
# 4.75-6.5 Lacs P.A.         5
# 4.25-6.5 Lacs P.A.         5
# 1.8-4.8 Lacs P.A.          5
# 1.44-1.92 Lacs P.A.        5
# 4.75-7 Lacs P.A.           5
# 60-75 Lacs P.A.            5
# 70,000-3 Lacs P.A.         5
# 5-9.5 Lacs P.A.            5
# 50,000-1.75 Lacs P.A.      5
# 3.6-9.6 Lacs P.A.          5
# 40-70 Lacs P.A.            5
# 14-18 Lacs P.A.            5
# 90,000-1.5 Lacs P.A.       5
# 60,000-1.25 Lacs P.A.      5
# 2.5-6.5 Lacs P.A.          5
# 1.2-6 Lacs P.A.            5
# 8-8.5 Lacs P.A.            5
# 17-30 Lacs P.A.            5
# 96,000-1.8 Lacs P.A.       5
# 7.5-8.5 Lacs P.A.          5
# 90,000-1.75 Lacs P.A.      5
# 3.25-4.75 Lacs P.A.        5
# 80,000-1 Lacs P.A.         5
# 8-17 Lacs P.A.             5
# 2.76-3 Lacs P.A.           4
# 11-16 Lacs P.A.            4
# 3.6-6.6 Lacs P.A.          4
# 1.2-4.2 Lacs P.A.          4
# 1.75-5 Lacs P.A.           4
# 1.44-1.68 Lacs P.A.        4
# 3.75-8.75 Lacs P.A.        4
# 13-22.5 Lacs P.A.          4
# 1.92-3 Lacs P.A.           4
# 9-17 Lacs P.A.             4
# 5.5-15.5 Lacs P.A.         4
# 1.68-1.92 Lacs P.A.        4
# 15-16 Lacs P.A.            4
# 1.8-2.64 Lacs P.A.         4
# 60,000-3 Lacs P.A.         4
# 72,000-1.2 Lacs P.A.       4
# 1.2-3 Lacs P.A.            4
# 6,000/month                4
# 8.5-16 Lacs P.A.           4
# 2.75-7.5 Lacs P.A.         4
# 6.5-16.5 Lacs P.A.         4
# 4.8-12 Lacs P.A.           4
# 13-19 Lacs P.A.            4
# 5.5-9 Lacs P.A.            4
# 8.5-11 Lacs P.A.           4
# 22.5-35 Lacs P.A.          4
# 7.5-15 Lacs P.A.           4
# 4.75-8.5 Lacs P.A.         4
# 11-13 Lacs P.A.            4
# 13-16 Lacs P.A.            4
# 9.5-13 Lacs P.A.           4
# 4.25-4.75 Lacs P.A.        4
# 27.5-35 Lacs P.A.          4
# 4.75-9.75 Lacs P.A.        4
# 50-75 Lacs P.A.            4
# 70,000-1.25 Lacs P.A.      4
# 40-80 Lacs P.A.            4
# 1.75 Lacs P.A.             4
# 6.5-9.5 Lacs P.A.          4
# 9.5-19.5 Lacs P.A.         4
# 25-37.5 Lacs P.A.          4
# 10-11 Lacs P.A.            4
# 16-27.5 Lacs P.A.          4
# 8.5-9 Lacs P.A.            3
# 5 Lacs P.A.                3
# 11-15 Lacs P.A.            3
# 7.5-13 Lacs P.A.           3
# 3.25-7.5 Lacs P.A.         3
# 60,000-80,000 P.A.         3
# 2.75-6.5 Lacs P.A.         3
# 1.8-5.4 Lacs P.A.          3
# 8.5-13 Lacs P.A.           3
# 2.88-3.6 Lacs P.A.         3
# 1.44-1.56 Lacs P.A.        3
# 1.56-2.4 Lacs P.A.         3
# 17-32 Lacs P.A.            3
# 3-7.2 Lacs P.A.            3
# 1-4.75 Lacs P.A.           3
# 9.6-18 Lacs P.A.           3
# 96,000-2.4 Lacs P.A.       3
# 4.25-9.25 Lacs P.A.        3
# 3-12 Lacs P.A.             3
# 1.68-3 Lacs P.A.           3
# 22.5-30 Lacs P.A.          3
# 3.36-4.2 Lacs P.A.         3
# 4.25-7 Lacs P.A.           3
# 3.75-6.5 Lacs P.A.         3
# 3.6-5.4 Lacs P.A.          3
# 2.76-3.6 Lacs P.A.         3
# 2.04-3 Lacs P.A.           3
# 5.5-9.5 Lacs P.A.          3
# 1.75-6 Lacs P.A.           3
# 1.8-2.52 Lacs P.A.         3
# 60-80 Lacs P.A.            3
# 96,000-1.92 Lacs P.A.      3
# 60,000-1.2 Lacs P.A.       3
# 1.08-1.8 Lacs P.A.         3
# 75 Lacs-1 Cr P.A.          3
# 16-31 Lacs P.A.            3
# 90 Lacs-1 Cr P.A.          3
# 13-20 Lacs P.A.            3
# 27.5 Lacs P.A.             3
# 1.25-6 Lacs P.A.           3
# 9.5-12 Lacs P.A.           3
# 10 Lacs P.A.               3
# 18-19 Lacs P.A.            3
# 8.5-18.5 Lacs P.A.         3
# 19-34 Lacs P.A.            3
# 27.5-32.5 Lacs P.A.        3
# 19-22.5 Lacs P.A.          3
# 8-9.5 Lacs P.A.            3
# 16-17 Lacs P.A.            3
# 17-18 Lacs P.A.            3
# 35-75 Lacs P.A.            3
# 6-14.4 Lacs P.A.           3
# 10.8-13.2 Lacs P.A.        3
# 6 Lacs P.A.                3
# 1.8-2.76 Lacs P.A.         3
# 90,000-3 Lacs P.A.         3
# 35-95 Lacs P.A.            3
# 18-32.5 Lacs P.A.          3
# 18-24 Lacs P.A.            3
# 3-9 Lacs P.A.              3
# 2.4-3.36 Lacs P.A.         3
# 70,000-80,000 P.A.         3
# 1.2-1.68 Lacs P.A.         3
# 2.16-2.52 Lacs P.A.        3
# 6.5-14 Lacs P.A.           3
# 3.6-7.2 Lacs P.A.          3
# 4.25-7.5 Lacs P.A.         3
# 2-3 Cr P.A.                3
# 1.68-2.4 Lacs P.A.         3
# 11-17 Lacs P.A.            3
# 4.75-5 Lacs P.A.           3
# 19-27.5 Lacs P.A.          3
# 90,000-1.25 Lacs P.A.      3
# 4.8-7.8 Lacs P.A.          3
# 40-75 Lacs P.A.            3
# 6-24 Lacs P.A.             3
# 9.6-12 Lacs P.A.           2
# 15-35 Lacs P.A.            2
# 27.5-30 Lacs P.A.          2
# 17-27.5 Lacs P.A.          2
# 40-65 Lacs P.A.            2
# 35-37.5 Lacs P.A.          2
# 1.68-2.04 Lacs P.A.        2
# 1.92-2.16 Lacs P.A.        2
# 2.4-12 Lacs P.A.           2
# 45-75 Lacs P.A.            2
# 8.5-17 Lacs P.A.           2
# 5.4-9.6 Lacs P.A.          2
# 4.8-15 Lacs P.A.           2
# 4.8-14.4 Lacs P.A.         2
# 24-72 Lacs P.A.            2
# 90,000-2.5 Lacs P.A.       2
# 1.56-3 Lacs P.A.           2
# 7.2-12 Lacs P.A.           2
# 18-36 Lacs P.A.            2
# 1.62-3 Lacs P.A.           2
# 6-10.8 Lacs P.A.           2
# 3.6-24 Lacs P.A.           2
# 1-1.5 Cr P.A.              2
# 4.25-9 Lacs P.A.           2
# 5.5-11 Lacs P.A.           2
# 1.44-2.04 Lacs P.A.        2
# 4.2-9 Lacs P.A.            2
# 37.5-40 Lacs P.A.          2
# 6.5-16 Lacs P.A.           2
# 1.2-1.32 Lacs P.A.         2
# 30,000/month               2
# 7.2-8.4 Lacs P.A.          2
# 6.5-15 Lacs P.A.           2
# 11-14 Lacs P.A.            2
# 7.2-8.76 Lacs P.A.         2
# 7.5-17.5 Lacs P.A.         2
# 4.8-21.6 Lacs P.A.         2
# 72,000-1.44 Lacs P.A.      2
# 80,000-2.25 Lacs P.A.      2
# 4.8-5.4 Lacs P.A.          2
# 3-3.84 Lacs P.A.           2
# 90,000-2.25 Lacs P.A.      2
# 9.5-14 Lacs P.A.           2
# 1.98-2.58 Lacs P.A.        2
# 40 Lacs P.A.               2
# 6.5-7 Lacs P.A.            2
# 2.04-2.4 Lacs P.A.         2
# 84,000-1.2 Lacs P.A.       2
# 1.08-1.44 Lacs P.A.        2
# 1.68-1.8 Lacs P.A.         2
# 1.92-2.04 Lacs P.A.        2
# 2.75 Lacs P.A.             2
# 1.92-2.64 Lacs P.A.        2
# 17-25 Lacs P.A.            2
# 9-9.5 Lacs P.A.            2
# 1.68-2.16 Lacs P.A.        2
# 2-2.4 Lacs P.A.            2
# 96,000-3 Lacs P.A.         2
# 75-85 Lacs P.A.            2
# 60-85 Lacs P.A.            2
# 9.5-15 Lacs P.A.           2
# 45-65 Lacs P.A.            2
# 11,000/month               2
# 1.68-2.88 Lacs P.A.        2
# 3.48-3.6 Lacs P.A.         2
# 1.8-1.92 Lacs P.A.         2
# 4.75-9 Lacs P.A.           2
# 1 Lacs P.A.                2
# 7.5-17 Lacs P.A.           2
# 37.5-60 Lacs P.A.          2
# 84,000-1.8 Lacs P.A.       2
# 18,000/month               2
# 1.25-5.5 Lacs P.A.         2
# 2.4-9.6 Lacs P.A.          2
# 60,000-90,000 P.A.         2
# 80 Lacs-1 Cr P.A.          2
# 4.5 Lacs P.A.              2
# 1.2-1.56 Lacs P.A.         2
# 5.5-15 Lacs P.A.           2
# 90,000-2.75 Lacs P.A.      2
# 40 Lacs-1 Cr P.A.          2
# 4.8-9.6 Lacs P.A.          2
# 60,000-1.75 Lacs P.A.      2
# 14-19 Lacs P.A.            2
# 2.64-4.2 Lacs P.A.         2
# 27.5-42.5 Lacs P.A.        2
# 7.2-7.8 Lacs P.A.          2
# 1.5 Lacs P.A.              2
# 4 Lacs P.A.                2
# 40-55 Lacs P.A.            2
# 16-30 Lacs P.A.            2
# 2.4-2.76 Lacs P.A.         2
# 70-85 Lacs P.A.            2
# 2.64-6 Lacs P.A.           2
# 60,000-1.44 Lacs P.A.      2
# 70,000-1 Lacs P.A.         2
# 80-95 Lacs P.A.            2
# 3.6-3.96 Lacs P.A.         2
# 2.4-2.64 Lacs P.A.         2
# 15-17 Lacs P.A.            2
# 22,000/month               2
# 8.4-12 Lacs P.A.           2
# 0-6 Lacs P.A.              1
# 9 Lacs P.A.                1
# 1.8-2.1 Lacs P.A.          1
# 20 Lacs P.A.               1
# 1.44-6 Lacs P.A.           1
# 90,000-2 Lacs P.A.         1
# 55-65 Lacs P.A.            1
# 17-19 Lacs P.A.            1
# 10.2-12 Lacs P.A.          1
# 6.6-7.8 Lacs P.A.          1
# 1.8-2.88 Lacs P.A.         1
# 3.6-12 Lacs P.A.           1
# 24-48 Lacs P.A.            1
# 3.9-6 Lacs P.A.            1
# 24,000-1.44 Lacs P.A.      1
# 21.6-33.6 Lacs P.A.        1
# 1.2-2.64 Lacs P.A.         1
# 84,000-2.4 Lacs P.A.       1
# 12-48 Lacs P.A.            1
# 0-2.5 Lacs P.A.            1
# 32.5-45 Lacs P.A.          1
# 70,000-90,000 P.A.         1
# 84,000-6 Lacs P.A.         1
# 70,000-1.75 Lacs P.A.      1
# 2.4-4.5 Lacs P.A.          1
# 3-5.04 Lacs P.A.           1
# 5.5-14 Lacs P.A.           1
# 24-36 Lacs P.A.            1
# 11 Lacs P.A.               1
# 8.4-10.8 Lacs P.A.         1
# 9-10.8 Lacs P.A.           1
# 9.5 Cr and above P.A.      1
# 60,000-2.25 Lacs P.A.      1
# 3-3.96 Lacs P.A.           1
# 96,000-2.16 Lacs P.A.      1
# 84,000-4.8 Lacs P.A.       1
# 3.36-5.04 Lacs P.A.        1
# 32.5-37.5 Lacs P.A.        1
# 45-80 Lacs P.A.            1
# 11-20 Lacs P.A.            1
# 300,000/month              1
# 7.5-9.5 Lacs P.A.          1
# 55-60 Lacs P.A.            1
# 38.4-50.4 Lacs P.A.        1
# 36-72 Lacs P.A.            1
# 1.8-3.24 Lacs P.A.         1
# 90,000-1 Lacs P.A.         1
# 2.16-2.88 Lacs P.A.        1
# 25,000/month               1
# 55-70 Lacs P.A.            1
# 80 Lacs-1.5 Cr P.A.        1
# 1.56-2.04 Lacs P.A.        1
# 19-32.5 Lacs P.A.          1
# 65-80 Lacs P.A.            1
# 50,000-24 Lacs P.A.        1
# 37.5-65 Lacs P.A.          1
# 60,000-1.5 Lacs P.A.       1
# 9.5-19 Lacs P.A.           1
# 30 Lacs P.A.               1
# 27.5-37.5 Lacs P.A.        1
# 3.6-9 Lacs P.A.            1
# 35-65 Lacs P.A.            1
# 35-70 Lacs P.A.            1
# 19-30 Lacs P.A.            1
# 15-21 Lacs P.A.            1
# 36,000-1.2 Lacs P.A.       1
# 4.8-6.6 Lacs P.A.          1
# 5.1-18 Lacs P.A.           1
# 3.3-8.4 Lacs P.A.          1
# 72 Lacs-1.188 Cr P.A.      1
# 18-54 Lacs P.A.            1
# 32.5-35 Lacs P.A.          1
# 16-19 Lacs P.A.            1
# 45,000/month               1
# 15.6-18 Lacs P.A.          1
# 12-23 Lacs P.A.            1
# 0-20 Lacs P.A.             1
# 1.02-3 Lacs P.A.           1
# 65-75 Lacs P.A.            1
# 2 Lacs P.A.                1
# 1.5-2.25 Cr P.A.           1
# 9.6-14.4 Lacs P.A.         1
# 32.5-47.5 Lacs P.A.        1
# 50 Lacs-1 Cr P.A.          1
# 70 Lacs-1 Cr P.A.          1
# 85 Lacs-1 Cr P.A.          1
# 7.5-9 Lacs P.A.            1
# 50-65 Lacs P.A.            1
# 3.75-7 Lacs P.A.           1
# 60-90 Lacs P.A.            1
# 1-2 Cr P.A.                1
# 72,000-84,000 P.A.         1
# 28.8-30 Lacs P.A.          1
# 1.08-1.2 Lacs P.A.         1
# 35,000/month               1
# 2.4-6.6 Lacs P.A.          1
# 11-19 Lacs P.A.            1
# 2.16-2.22 Lacs P.A.        1
# 42,000-1.08 Lacs P.A.      1
# 3-8.4 Lacs P.A.            1
# 1.25-1.5 Cr P.A.           1
# 1 Cr P.A.                  1
# 2.28-2.88 Lacs P.A.        1
# 7.2-13.2 Lacs P.A.         1
# 13.2-24 Lacs P.A.          1
# 36-48 Lacs P.A.            1
# 3.36-3.6 Lacs P.A.         1
# 0-23 Lacs P.A.             1
# 2.16-3.36 Lacs P.A.        1
# 33-36 Lacs P.A.            1
# 6-10.2 Lacs P.A.           1
# 30-36 Lacs P.A.            1
# 2.28-4.2 Lacs P.A.         1
# 3-9.6 Lacs P.A.            1
# 1.8-7.2 Lacs P.A.          1
# 15-60 Lacs P.A.            1
# 4.8-6.48 Lacs P.A.         1
# 15-42 Lacs P.A.            1
# 15-48 Lacs P.A.            1
# 2.16-3.12 Lacs P.A.        1
# 19-20 Lacs P.A.            1
# 7.2-10.8 Lacs P.A.         1
# 4.8-8.4 Lacs P.A.          1
# 2.52-4.2 Lacs P.A.         1
# 3-7.8 Lacs P.A.            1
# 2.76-3.96 Lacs P.A.        1
# 1.44-4.8 Lacs P.A.         1
# 9.5-11 Lacs P.A.           1
# 20,000-25,000 P.A.         1
# 24,000-60,000 P.A.         1
# 1.75-4.2 Lacs P.A.         1
# 4.25-8.5 Lacs P.A.         1
# 1.98-2.7 Lacs P.A.         1
# 2.52-4.8 Lacs P.A.         1
# 2.52-3.6 Lacs P.A.         1
# 40,000-45,000 P.A.         1
# 2.76-3.36 Lacs P.A.        1
# 96,000-3.6 Lacs P.A.       1
# 2.28-2.34 Lacs P.A.        1
# 4.25-8 Lacs P.A.           1
# 2.16 Lacs P.A.             1
# 8.5-9.5 Lacs P.A.          1
# 1.2-5.4 Lacs P.A.          1
# 4.75-9.5 Lacs P.A.         1
# 2.4-3.84 Lacs P.A.         1
# 2.16-3.3 Lacs P.A.         1
# 4.5-7.2 Lacs P.A.          1
# 3.96-6 Lacs P.A.           1
# 3.3-3.6 Lacs P.A.          1
# 8.5-18 Lacs P.A.           1
# 3.25-8 Lacs P.A.           1
# 2.4-7.2 Lacs P.A.          1
# 2.64-4.38 Lacs P.A.        1
# 3.6-8.4 Lacs P.A.          1
# 48,000-1.2 Lacs P.A.       1
# 5.4-7.2 Lacs P.A.          1
# 60,000-72,000 P.A.         1
# 2.88-4.2 Lacs P.A.         1
# 3-3.36 Lacs P.A.           1
# 7.2-9 Lacs P.A.            1
# 9.5-16 Lacs P.A.           1
# 3.5 Lacs P.A.              1
# 48,000-96,000 P.A.         1
# 12,000-1.8 Lacs P.A.       1
# 99,000-3 Lacs P.A.         1
# 1.8-9.6 Lacs P.A.          1
# 60,000-2.4 Lacs P.A.       1
# 80,000-1.5 Lacs P.A.       1
# 72-90 Lacs P.A.            1
# 4.8-13.2 Lacs P.A.         1
# 3.36-5.4 Lacs P.A.         1
# 90 Lacs-1.5 Cr P.A.        1
# 2.16-2.76 Lacs P.A.        1
# 75 Lacs-1.5 Cr P.A.        1
# 2.04-2.64 Lacs P.A.        1
# 1.92-2.28 Lacs P.A.        1
# 1.68-4.2 Lacs P.A.         1
# 1.56-3.48 Lacs P.A.        1
# 1.92-2.4 Lacs P.A.         1
# 4.2-6.6 Lacs P.A.          1
# 7.2-9.6 Lacs P.A.          1
# 1.14-1.2 Lacs P.A.         1
# 72,000-1.68 Lacs P.A.      1
# 7-7.5 Lacs P.A.            1
# 8.5-14 Lacs P.A.           1
# 96,000-1.68 Lacs P.A.      1
# 2.04-2.28 Lacs P.A.        1
# 15,000-20,000 P.A.         1
# 85-90 Lacs P.A.            1
# 3.36-4.8 Lacs P.A.         1
# 12,000-3.6 Lacs P.A.       1
# 1.98-2.22 Lacs P.A.        1
# 1.68-2.52 Lacs P.A.        1
# 2.52-3.36 Lacs P.A.        1
# 2.64-3.36 Lacs P.A.        1
# 2.76-2.88 Lacs P.A.        1
# 2.28-2.52 Lacs P.A.        1
# 7,500/month                1
# 3.6-3.84 Lacs P.A.         1
# 1.25 Lacs P.A.             1
# 20,000-30,000 P.A.         1
# 1.76-5.5 Lacs P.A.         1
# 10,000-20,000 P.A.         1
# 1.44-3 Lacs P.A.           1
# 60-65 Lacs P.A.            1
# 60,000-2.75 Lacs P.A.      1
# 60,000 P.A.                1
# 80,000-2.5 Lacs P.A.       1
# 7,000/month                1
# 1.2-1.92 Lacs P.A.         1
# 6.5-11 Lacs P.A.           1
# 2.52-3 Lacs P.A.           1
# 1.8-3.12 Lacs P.A.         1
# 4.2-4.32 Lacs P.A.         1
# 4.25-4.5 Lacs P.A.         1
# 8.5-15 Lacs P.A.           1
# 1.02-1.8 Lacs P.A.         1
# 70 Lacs P.A.               1
# 1.92-3.36 Lacs P.A.        1
# 3.6-7.8 Lacs P.A.          1
# 60,000-3.6 Lacs P.A.       1
# 21.6-24 Lacs P.A.          1
# 1.32-2.16 Lacs P.A.        1
# 1.32-2.76 Lacs P.A.        1
# 18.72-26.4 Lacs P.A.       1
# 7.5-14 Lacs P.A.           1
# 48-60 Lacs P.A.            1
# 96,000-2.04 Lacs P.A.      1
# 9.5-10 Lacs P.A.           1
# 6.6-9 Lacs P.A.            1
# 50 Lacs P.A.               1
# Name: count, dtype: int64

# %%
def value_lacsPA(value):
    if '-' in value:
        lower, upper = value.split("-")
        if "Lacs P.A." in  upper:
            upper= upper.replace("Lacs P.A.","")
            if ',' in lower:
                lower = lower.replace(",","")
            lower = float(lower)
            upper = float(upper)
            if lower<1000 and upper<1000:
                return f"{lower*100000}-{upper*100000}"
            elif lower>1000 and upper<1000:
                return f"{lower}-{upper*100000}"
            elif lower<1000 and upper>1000:
                return f"{lower*100000}-{upper}"
            elif lower >1000 and upper >1000:
                return f"{lower}-{upper}"
    return value

# %%
df['Salary'] = df['Salary'].apply(value_lacsPA)

# %%
def convert_monthly_to_annual(salary):
    if '/month' in salary: 
        monthly_salary = float(salary.replace('/month', '').replace(',', ''))
        annual_salary = monthly_salary * 12
        return f"{annual_salary}"
    return salary

# %%
df['Salary']  = df['Salary'].apply(convert_monthly_to_annual)

# %%
def existslacspa(value):
    if 'Lacs P.A.' in value:
        value = value.replace('Lacs P.A.',"")
        return f"{float(value)*100000}"
    return value

# %%
df['Salary']  = df['Salary'].apply(existslacspa)

# %%
df['Salary']=df['Salary'].str.replace("P.A.","",regex=False)

# %%
def funcforCrLac(value):
    if 'and' in value:
        value1,value2 = value.split("and")
        value1 = value1.replace("Cr", "")
        
        value1 = float(value1)*10000000
        return f"{value1}"
        
    if "Cr" in value:
        if '-' in value:
            lower, upper = value.split("-")
            if "Lacs" in lower:
                lower = lower.replace("Lacs","")
                upper = upper.replace("Cr","")
                lower = float(lower)*100000
                upper = float(upper)*10000000
                return f"{lower}-{upper}"
    
            upper = upper.replace("Cr","")
            lower = float(lower)*10000000
            upper = float(upper)*10000000
            return  f"{lower}-{upper}"
        else:
            value = value.replace("Cr","")
            value = float(value)*10000000
            return f"{value}"
    return f"{value}"

# %%
df['Salary'] = df['Salary'].apply(funcforCrLac)

# %%
def removecommas(value):
    if '-' in value:
        lower, upper = value.split("-")
        if ',' in lower :
            lower = lower.replace(",","")
        if ',' in upper:
            upper = upper.replace(",","")
        return f"{lower}-{upper}"
    elif ',' in value:
        return f"{value.replace(",","")}"
    else:
        return value

# %%
df['Salary'] = df['Salary'].apply(removecommas)

# %%
def functForMeanSal(value):
    if '-' in value:
        lower, upper = value.split("-")
        lower = float(lower)
        upper = float(upper)
        mean = (upper+lower)/2
        return mean
    elif value == 'Unpaid':
        return 0
    else:
        value = float(value)
        return value

# %%
df['Salary'] = df['Salary'].apply(functForMeanSal)

# %%
def salCategories(value):
    if 0 <= value <350000:
        return '[0,350000]'
    elif 350000 <= value <600000:
        return '[350000,600000]'
    elif 600000 <= value <1000000:
        return '[600000,1000000]'
    elif 1000000 <= value <=1500000:
        return '[1000000,1500000]'
    elif value>1500000:
        return 'above 1500000'

# %%
df['labelSal'] = df['Salary'].apply(salCategories)

# %%
df['labelSal'].value_counts()
# Out:
# labelSal
# [0,350000]           6629
# [350000,600000]      5102
# above 1500000        2110
# [600000,1000000]     2052
# [1000000,1500000]    1505
# Name: count, dtype: int64

# %%
df['labelSal'] = LabelEncoder().fit_transform(df['labelSal'])

# %%
df['labelSal'].value_counts()
# Out:
# labelSal
# 0    6629
# 2    5102
# 4    2110
# 3    2052
# 1    1505
# Name: count, dtype: int64

# %%
df = df.drop('Salary', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17398 entries, 0 to 56684
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Experience_Category  17398 non-null  int32
#  1   City                 17398 non-null  int32
#  2   UG_Encoded           17398 non-null  int64
#  3   PG_Encoded           17398 non-null  int64
#  4   Department           17398 non-null  int32
#  5   Role Category        17398 non-null  int32
#  6   labelSal             17398 non-null  int32
# dtypes: int32(5), int64(2)
# memory usage: 747.6 KB

# %%
df.corr()['labelSal']
# Out:
# Experience_Category   -0.080010
# City                  -0.076445
# UG_Encoded             0.072249
# PG_Encoded             0.171511
# Department            -0.034042
# Role Category          0.109505
# labelSal               1.000000
# Name: labelSal, dtype: float64

# %%
# decide the x and y
x = df.drop('labelSal', axis=1)
y = df['labelSal']

# %%
# split the data into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=123456)

# %%
from xgboost import XGBClassifier
model = XGBClassifier(colsample_bytree= 0.8, learning_rate= 0.1, max_depth= 7, n_estimators= 100, subsample= 0.8)
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

y_pred_train = model.predict(x_train)
y_true_train = y_train

# calculate training accuracy
training_accuracy = accuracy_score(y_true_train, y_pred_train)

# testing accuracy
y_pred_test = model.predict(x_test)
y_true_test = y_test

# get the performance metrics for testing
testing_accuracy = accuracy_score(y_true_test, y_pred_test)
testing_precision = precision_score(y_true_test, y_pred_test,average='macro')
testing_recall = recall_score(y_true_test, y_pred_test,average='macro')
testing_f1 = f1_score(y_true_test, y_pred_test,average='macro')

# %%
print("training_accuracy", training_accuracy)
print("testing_accuracy = ", testing_accuracy)
print("testing_precision = ", testing_precision)
print("testing_recall = ", testing_recall)
print("testing_f1 = ", testing_f1)
# Out:
# training_accuracy 0.6732289122000288
# testing_accuracy =  0.6048850574712644
# testing_precision =  0.5410756035215661
# testing_recall =  0.5274819342448905
# testing_f1 =  0.5274256422146125

# %% [markdown]
# # Imputing Values

# %%
not_disclosed_df = not_disclosed_df.drop('Salary', axis=1)

# %%
# Step 3: Predict salaries using the trained model
predicted_salaries = model.predict(not_disclosed_df)

# %%
# Step 4: Assign predicted salaries to the filtered dataset
not_disclosed_df['Predicted_Salary'] = predicted_salaries

# %%
not_disclosed_df.head()
# Out:
#    Experience_Category  City  UG_Encoded  PG_Encoded  Department  \
# 1                    0     1           1           1           1
# 2                    0     1           1           1           1
# 3                    3     8           1           1           1
# 4                    3    11           1           1           1
# 6                    1    11           1           1           1
#
#    Role Category  Predicted_Salary
# 1              7                 2
# 2             47                 0
# 3              7                 0
# 4             47                 0
# 6              7                 1

# %%
not_disclosed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37303 entries, 1 to 56681
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Experience_Category  37303 non-null  int32
#  1   City                 37303 non-null  int32
#  2   UG_Encoded           37303 non-null  int64
#  3   PG_Encoded           37303 non-null  int64
#  4   Department           37303 non-null  int32
#  5   Role Category        37303 non-null  int32
#  6   Predicted_Salary     37303 non-null  int64
# dtypes: int32(4), int64(3)
# memory usage: 1.7 MB

# %%
not_disclosed_df['Predicted_Salary'].value_counts()
# Out:
# Predicted_Salary
# 4    13804
# 2     8252
# 0     7379
# 3     5964
# 1     1904
# Name: count, dtype: int64

# %%
not_disclosed_df.rename(columns = {'Predicted_Salary':'labelSal'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17398 entries, 0 to 56684
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Experience_Category  17398 non-null  int32
#  1   City                 17398 non-null  int32
#  2   UG_Encoded           17398 non-null  int64
#  3   PG_Encoded           17398 non-null  int64
#  4   Department           17398 non-null  int32
#  5   Role Category        17398 non-null  int32
#  6   labelSal             17398 non-null  int32
# dtypes: int32(5), int64(2)
# memory usage: 747.6 KB

# %% [markdown]
# # Merging both dataframes

# %%
# Ensure both DataFrames have the same columns
assert set(df.columns) == set(not_disclosed_df.columns), "Column mismatch between the DataFrames!"

# %%
# Merge the DataFrames
final_df = pd.concat([df, not_disclosed_df], ignore_index=True)

# Shuffle the data
final_df = final_df.sample(frac=1, random_state=69).reset_index(drop=True)

# %%
x = final_df.drop('labelSal', axis=1)
y = final_df['labelSal']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=123456)

# %%
from xgboost import XGBClassifier
model = XGBClassifier(colsample_bytree= 0.8, learning_rate= 0.1, max_depth= 7, n_estimators= 100, subsample= 0.8)
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
catboost_model = CatBoostClassifier(logging_level='Silent')
catboost_model.fit(x_train, y_train)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# Define parameter grid
param_grid = {
    'iterations': [100, 200],
    'depth': [4, 6, 8],
    'learning_rate': [0.01, 0.1],
    'l2_leaf_reg': [1, 3, 5]
}

# Wrap the model for GridSearchCV
grid_search = GridSearchCV(
    estimator=catboost_model, 
    param_grid=param_grid, 
    cv=3, 
    scoring='accuracy', 
    n_jobs=-1, 
    verbose=2
)

# Perform grid search
grid_search.fit(x_train, y_train)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)

# %%
gb_model = GradientBoostingClassifier()
gb_model.fit(x_train, y_train)

# %%
param_grid = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 1.0],
}
grid_search_gbc = GridSearchCV(estimator=gb_model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=2, n_jobs=-1)
grid_search_gbc.fit(x_train, y_train)

# %%
print("Best Parameters:", grid_search_gbc.best_params_)
print("Best CV Score:", grid_search_gbc.best_score_)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

y_pred_train = model.predict(x_train)
y_true_train = y_train

# calculate training accuracy
training_accuracy = accuracy_score(y_true_train, y_pred_train)

# testing accuracy
y_pred_test = model.predict(x_test)
y_true_test = y_test

# get the performance metrics for testing
testing_accuracy = accuracy_score(y_true_test, y_pred_test)
testing_precision = precision_score(y_true_test, y_pred_test,average='macro')
testing_recall = recall_score(y_true_test, y_pred_test,average='macro')
testing_f1 = f1_score(y_true_test, y_pred_test,average='macro')

# %%
print("training_accuracy", training_accuracy)
print("testing_accuracy = ", testing_accuracy)
print("testing_precision = ", testing_precision)
print("testing_recall = ", testing_recall)
print("testing_f1 = ", testing_f1)
# Out:
# training_accuracy 0.869926873857404
# testing_accuracy =  0.8630838131797824
# testing_precision =  0.8446035301806551
# testing_recall =  0.8154359729120072
# testing_f1 =  0.8273715515392919

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54701 entries, 0 to 54700
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Experience_Category  54701 non-null  int32
#  1   City                 54701 non-null  int32
#  2   UG_Encoded           54701 non-null  int64
#  3   PG_Encoded           54701 non-null  int64
#  4   Department           54701 non-null  int32
#  5   Role Category        54701 non-null  int32
#  6   labelSal             54701 non-null  int64
# dtypes: int32(4), int64(3)
# memory usage: 2.1 MB

# %%
final_df["labelSal"].value_counts()
